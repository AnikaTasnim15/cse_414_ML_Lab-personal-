# %% [markdown]
# # Seaborn

# %%
import pandas as pd
import seaborn as sns

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.describe(include='all')
# Out:
#         total_bill         tip   sex smoker  day    time        size
# count   244.000000  244.000000   244    244  244     244  244.000000
# unique         NaN         NaN     2      2    4       2         NaN
# top            NaN         NaN  Male     No  Sat  Dinner         NaN
# freq           NaN         NaN   157    151   87     176         NaN
# mean     19.785943    2.998279   NaN    NaN  NaN     NaN    2.569672
# std       8.902412    1.383638   NaN    NaN  NaN     NaN    0.951100
# min       3.070000    1.000000   NaN    NaN  NaN     NaN    1.000000
# 25%      13.347500    2.000000   NaN    NaN  NaN     NaN    2.000000
# 50%      17.795000    2.900000   NaN    NaN  NaN     NaN    2.000000
# 75%      24.127500    3.562500   NaN    NaN  NaN     NaN    3.000000
# max      50.810000   10.000000   NaN    NaN  NaN     NaN    6.000000

# %%
tips.day.value_counts()
tips.time.value_counts()
# Out:
# time
# Dinner    176
# Lunch      68
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
tips.tip.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
from collections import Counter
Counter(tips.tip)
# Out:
# Counter({2.0: 33,
#          3.0: 23,
#          4.0: 12,
#          5.0: 10,
#          2.5: 10,
#          3.5: 9,
#          1.5: 9,
#          1.0: 4,
#          1.25: 3,
#          3.48: 3,
#          3.23: 2,
#          4.08: 2,
#          2.75: 2,
#          2.23: 2,
#          3.18: 2,
#          4.3: 2,
#          2.31: 2,
#          2.24: 2,
#          3.76: 2,
#          2.01: 2,
#          2.2: 2,
#          2.03: 2,
#          3.25: 2,
#          6.5: 2,
#          1.44: 2,
#          1.01: 1,
#          1.66: 1,
#          3.31: 1,
#          3.61: 1,
#          4.71: 1,
#          3.12: 1,
#          1.96: 1,
#          1.71: 1,
#          1.57: 1,
#          3.02: 1,
#          3.92: 1,
#          1.67: 1,
#          3.71: 1,
#          3.35: 1,
#          7.58: 1,
#          2.34: 1,
#          1.45: 1,
#          2.45: 1,
#          3.27: 1,
#          3.6: 1,
#          3.07: 1,
#          2.54: 1,
#          3.06: 1,
#          1.32: 1,
#          5.6: 1,
#          6.0: 1,
#          2.05: 1,
#          2.6: 1,
#          5.2: 1,
#          1.56: 1,
#          4.34: 1,
#          3.51: 1,
#          1.76: 1,
#          6.73: 1,
#          3.21: 1,
#          1.98: 1,
#          2.64: 1,
#          3.15: 1,
#          2.47: 1,
#          2.09: 1,
#          1.97: 1,
#          3.14: 1,
#          3.08: 1,
#          2.71: 1,
#          3.4: 1,
#          1.83: 1,
#          5.17: 1,
#          5.85: 1,
#          4.73: 1,
#          1.64: 1,
#          4.06: 1,
#          4.29: 1,
#          2.55: 1,
#          5.07: 1,
#          1.8: 1,
#          2.92: 1,
#          1.68: 1,
#          2.52: 1,
#          4.2: 1,
#          1.48: 1,
#          2.18: 1,
#          2.83: 1,
#          6.7: 1,
#          2.3: 1,
#          1.36: 1,
#          1.63: 1,
#          1.73: 1,
#          2.74: 1,
#          5.14: 1,
#          3.75: 1,
#          2.61: 1,
#          4.5: 1,
#          1.61: 1,
#          10.0: 1,
#          3.16: 1,
#          5.15: 1,
#          3.11: 1,
#          3.55: 1,
#          3.68: 1,
#          5.65: 1,
#          4.19: 1,
#          2.56: 1,
#          2.02: 1,
#          3.41: 1,
#          5.16: 1,
#          9.0: 1,
#          1.1: 1,
#          3.09: 1,
#          1.92: 1,
#          1.58: 1,
#          2.72: 1,
#          2.88: 1,
#          3.39: 1,
#          1.47: 1,
#          1.17: 1,
#          4.67: 1,
#          5.92: 1,
#          1.75: 1})

# %%
from IPython.display import HTML

HTML("""
<iframe width="560" height="315" src="https://www.youtube.com/embed/5rNu16O3YNE?si=_xKkc0N65yO1J-lo" 
title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; 
encrypted-media; gyroscope; picture-in-picture; web-share" 
referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>
""")
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/5rNu16O3YNE?si=_xKkc0N65yO1J-lo"
# title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write;
# encrypted-media; gyroscope; picture-in-picture; web-share"
# referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>

# %%
import math
tips.tip = tips.tip.map(lambda x: math.floor(x))
Counter(tips.tip)
# Out:
# Counter({2: 78, 3: 68, 1: 45, 4: 25, 5: 20, 6: 5, 7: 1, 10: 1, 9: 1})

# %%
tips.smoker.value_counts()
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %%
tips.smoker.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='smoker'>

# %%
sns.countplot(x='smoker', data=tips, palette='flare')
# Out:
# /var/folders/s7/nhlmv2hx4vg32r27lhnh40t00000gn/T/ipykernel_70535/592652257.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='smoker', data=tips, palette='flare')
# <Axes: xlabel='smoker', ylabel='count'>

# %%
sns.distplot(tips.total_bill, kde=False)
# Out:
# /var/folders/s7/nhlmv2hx4vg32r27lhnh40t00000gn/T/ipykernel_70535/346489149.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips.total_bill, kde=False)
# <Axes: xlabel='total_bill'>

# %%
sns.distplot(tips.total_bill, kde=True)
# Out:
# /var/folders/s7/nhlmv2hx4vg32r27lhnh40t00000gn/T/ipykernel_70535/21351172.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips.total_bill, kde=True)
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, fit_reg=True, hue='sex', col='smoker', row='day')

# %%
facet = sns.FacetGrid(tips, col='time', row='smoker', hue='sex')
facet.map(plt.scatter,'total_bill', 'tip')

# %%
fig, ax = plt.subplots(1,1)
ax.scatter(tips.tip, tips.total_bill)

# %%
fig, (ax1, ax2) = plt.subplots(1,2)
ax1.scatter(tips.tip, tips.total_bill)
ax2.hist(tips.total_bill)
# Out:
# (array([ 7., 42., 68., 51., 31., 19., 12.,  7.,  3.,  4.]),
#  array([ 3.07 ,  7.844, 12.618, 17.392, 22.166, 26.94 , 31.714, 36.488,
#         41.262, 46.036, 50.81 ]),
#  <BarContainer object of 10 artists>)

# %%
fig, (ax1, ax2) = plt.subplots(1,2)
sns.distplot(tips.tip, ax=ax1)
sns.regplot(x='total_bill', y='tip', data=tips, ax=ax2)
# Out:
# /var/folders/s7/nhlmv2hx4vg32r27lhnh40t00000gn/T/ipykernel_70535/4023707836.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips.tip, ax=ax1)
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# # Matplotlib

# %%
import matplotlib.pyplot as plt
# %matplotlib inline 

x=[1,2,3,4,5]
y=[10,5,14,20,3]
plt.plot(x,y)
plt.xlabel('AGE')
plt.ylabel('age')
plt.title('Relation between ages')
plt.show() # This is not necessary when using %matplotlib inline

# %%
x=[1,2,3,4,5,6,7]
y=[50,51,52,45,41,47,49]
plt.xlabel('Day')
plt.ylabel('Temp')
plt.title('Weather forecast')
plt.plot(x,y, color='green', linewidth=2, linestyle='-')
# plt.plot(x,y, color='green', linewidth=4, linestyle='--')
# plt.plot(x,y, color='green', linewidth=4, linestyle='-.')
# plt.plot(x,y, color='green', linewidth=4, linestyle=':')
# plt.plot(x,y, color='purple', linewidth=4, linestyle=':')
plt.show()

# %%
x=[1,2,3,4,5,6,7]
y=[50,51,52,45,41,47,49]
plt.xlabel('Day')
plt.ylabel('Temp')
plt.title('Weather forecast')
plt.plot(x,y, 'r*:')
plt.show()

# %%
plt.plot(x,y, color='blue', marker='*', linestyle='')
plt.show()

# %%
plt.plot(x,y, color='red', marker='*', linestyle=':')
plt.show()

# %%
days=[1,2,3,4,5,6,7]
max_t=[50,51,52,54,50,49,47]
min_t=[40,41,42,45,39,42,41]
avg_t = [45,46,47,44,43,45,48]


plt.xlabel('Day')
plt.ylabel('Temp')
plt.title('weather')
plt.plot(days,max_t, label='max temp')
plt.plot(days,min_t, label='min temp')
plt.plot(days,avg_t, label='avg temp')
plt.legend(shadow=True, fontsize='large')
plt.show()

# %%
import numpy as np
company = ['google', 'facebook', 'amazon', 'tesla']
revenue=[15,20,30,70]
#xlabel
#ylabel
#title
xpos = np.arange(len(company))
plt.xticks(xpos,company)
plt.bar(xpos, revenue, label='revenue')
plt.legend()
plt.show()

# %%
profit=[10,15,25,65]
plt.bar(xpos-0.2, revenue, width=0.4, label='revenue')
plt.bar(xpos+0.2, profit, width=0.4, label='profit')
plt.xticks(xpos,company)
#XY label
#title
plt.legend()
plt.show()

# %%
plt.barh(xpos, revenue)
plt.yticks(xpos,company)
plt.show()

# %%
blood_sugar = [113,85,90,150,149,88,91,115,135,80,77,82,129]
plt.hist(blood_sugar, rwidth=0.8)
plt.show()

# %%
plt.hist(blood_sugar, rwidth=0.5, bins=4, color='g')
plt.show()

# %%
plt.xlabel('sugar level')
plt.ylabel('number of patients')
plt.title('blood sugar chart')

bl_sg_m = [113,85,90,150, 149 , 88, 93,115,135,80,77,82,129]
bl_sg_f = [67,98,89,120,133,150,84,69,89,79,120,112,100]
plt.hist([bl_sg_m, bl_sg_f], bins=[80,100,125,150], rwidth=0.95, color=['blue', 'green'], label=['male','woman'])
plt.legend()
plt.show()

# %%
val = [1400,600,300,400,500]
labels = ['rent','emi','utility','car','others']
plt.pie(val,labels=labels)
plt.axis('equal')
plt.show()

# %%
plt.axis('equal')
plt.pie(val, labels=labels, shadow=True, autopct='%1.1f%%', radius=1)
plt.show()

# %%
plt.axis('equal')
plt.pie(val, labels=labels, shadow=False, autopct='%1.1f%%', radius=1, explode=[0,0,0,0,0.3])
plt.show()

# %% [markdown]
# # Folium

# %%
# !pip install folium
# Out:
# Requirement already satisfied: folium in /opt/anaconda3/lib/python3.12/site-packages (0.20.0)
# Requirement already satisfied: branca>=0.6.0 in /opt/anaconda3/lib/python3.12/site-packages (from folium) (0.8.2)
# Requirement already satisfied: jinja2>=2.9 in /opt/anaconda3/lib/python3.12/site-packages (from folium) (3.1.4)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.12/site-packages (from folium) (1.26.4)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.12/site-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in /opt/anaconda3/lib/python3.12/site-packages (from folium) (2022.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.12/site-packages (from jinja2>=2.9->folium) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests->folium) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests->folium) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests->folium) (2024.8.30)

# %%
import folium as fm

lat, lon = 37.677150, -97.463980
m=fm.Map(location=[lat,lon], zoom_start=20, control_scale=True)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_43f358342424032537fb04da22e2a43b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_43f358342424032537fb04da22e2a43b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_43f358342424032537fb04da22e2a43b = L.map(
#                 &quot;map_43f358342424032537fb04da22e2a43b&quot;,
#                 {
#                     center: [37.67715, -97.46398],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 20,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_43f358342424032537fb04da22e2a43b);
#
#
#
#
#
#             var tile_layer_533905ef714383dd20b961fa87e2559c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_533905ef714383dd20b961fa87e2559c.addTo(map_43f358342424032537fb04da22e2a43b);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m.save('base_map.html')

# %%
lat, lon = 37.677150, -97.463980
m=fm.Map(location=[lat,lon], zoom_start=20, control_scale=True)
fm.Marker(
    location=[lat,lon],
    popop='My home sweet home',
    icon=fm.Icon(color='green', icon='ok-sign')
).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c565fecb6642da0df9d51fd977a97568 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c565fecb6642da0df9d51fd977a97568&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c565fecb6642da0df9d51fd977a97568 = L.map(
#                 &quot;map_c565fecb6642da0df9d51fd977a97568&quot;,
#                 {
#                     center: [37.67715, -97.46398],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 20,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_c565fecb6642da0df9d51fd977a97568);
#
#
#
#
#
#             var tile_layer_a3e304a14aba116b30f9a5e97a5095c3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a3e304a14aba116b30f9a5e97a5095c3.addTo(map_c565fecb6642da0df9d51fd977a97568);
#
#
#             var marker_8b09a5cff59f4330657bc03c8a6c858b = L.marker(
#                 [37.67715, -97.46398],
#                 {
#   &quot;popop&quot;: &quot;My home sweet home&quot;,
# }
#             ).addTo(map_c565fecb6642da0df9d51fd977a97568);
#
#
#             var icon_ba0446fe349f48b1d6d60b2e73929b1d = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;ok-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#                 marker_8b09a5cff59f4330657bc03c8a6c858b.setIcon(icon_ba0446fe349f48b1d6d60b2e73929b1d);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import seaborn as sns
flw = sns.load_dataset('iris')
flw
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
flw.species.value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
setosa = flw[flw.species=='setosa']
sns.boxplot(setosa[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']])
plt.show()

# %%
sns.boxplot(flw[flw.species=='versicolor'][['sepal_length', 'sepal_width', 'petal_length', 'petal_width']])
plt.show()

# %%
sns.boxplot(flw[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']])

plt.show()

# %%
sns.scatterplot(x=flw.sepal_length,
                y=flw.sepal_width,
                hue=flw.species)
plt.show()

# %%
sns.lmplot(x='sepal_length', y='sepal_width', data=flw, fit_reg=True, hue='species')
plt.show()

# %%
yr = range(2000,2006)
app = [0.35,0.6,0.9,0.8,0.67,0.8]
oranges = [0.4, 0.8, 0.9, 0.7, 0.6, 0.8]

plt.bar(yr, oranges)
plt.plot(yr, oranges, 'o--r')
plt.show()

# %%
flights = sns.load_dataset('flights').pivot(index="month", columns='year')
flights
# Out:
#       passengers
# year        1949 1950 1951 1952 1953 1954 1955 1956 1957 1958 1959 1960
# month
# Jan          112  115  145  171  196  204  242  284  315  340  360  417
# Feb          118  126  150  180  196  188  233  277  301  318  342  391
# Mar          132  141  178  193  236  235  267  317  356  362  406  419
# Apr          129  135  163  181  235  227  269  313  348  348  396  461
# May          121  125  172  183  229  234  270  318  355  363  420  472
# Jun          135  149  178  218  243  264  315  374  422  435  472  535
# Jul          148  170  199  230  264  302  364  413  465  491  548  622
# Aug          148  170  199  242  272  293  347  405  467  505  559  606
# Sep          136  158  184  209  237  259  312  355  404  404  463  508
# Oct          119  133  162  191  211  229  274  306  347  359  407  461
# Nov          104  114  146  172  180  203  237  271  305  310  362  390
# Dec          118  140  166  194  201  229  278  306  336  337  405  432

# %%
plt.title("No. of passengers")
sns.heatmap(flights)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 15))
sns.heatmap(flights, fmt=".2f", annot=True, cmap="Blues", ax=ax)
ax.set_title("No. of passengers")
plt.show()

# %%
plt.figure(figsize=(8,8))
plt.rcParams.update({'font.size':12})
sns.heatmap(flights, fmt='d', annot=True, cmap='Blues', vmin=100, vmax=622, square=True,linewidth=1.4)
plt.show()

# %%
plt.title("Flower")
sns.kdeplot(data = flw, x='sepal_length', y='sepal_width', shade=True, shade_lowest=False)
sns.lmplot(data = flw, x='sepal_length', y='sepal_width', fit_reg=False)
plt.show()
# Out:
# /var/folders/s7/nhlmv2hx4vg32r27lhnh40t00000gn/T/ipykernel_70535/4094848044.py:2: UserWarning:
#
# `shade_lowest` has been replaced by `thresh`; setting `thresh=0.05.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data = flw, x='sepal_length', y='sepal_width', shade=True, shade_lowest=False)
# /var/folders/s7/nhlmv2hx4vg32r27lhnh40t00000gn/T/ipykernel_70535/4094848044.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data = flw, x='sepal_length', y='sepal_width', shade=True, shade_lowest=False)

# %%
plt.title("Flower")
sns.kdeplot(data = flw[flw.species=='setosa'], x='sepal_length', y='sepal_width', shade=True, shade_lowest=False, cmap='Reds')
sns.kdeplot(data = flw[flw.species=='virginica'], x='sepal_length', y='sepal_width', shade=True, shade_lowest=False, cmap='Blues')
# sns.kdeplot(data = flw[flw.species=='versicolor'], x='sepal_length', y='sepal_width', shade=True, shade_lowest=False, cmap='Greens')
plt.show()
# Out:
# /var/folders/s7/nhlmv2hx4vg32r27lhnh40t00000gn/T/ipykernel_70535/2952415658.py:2: UserWarning:
#
# `shade_lowest` has been replaced by `thresh`; setting `thresh=0.05.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data = flw[flw.species=='setosa'], x='sepal_length', y='sepal_width', shade=True, shade_lowest=False, cmap='Reds')
# /var/folders/s7/nhlmv2hx4vg32r27lhnh40t00000gn/T/ipykernel_70535/2952415658.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data = flw[flw.species=='setosa'], x='sepal_length', y='sepal_width', shade=True, shade_lowest=False, cmap='Reds')
# /var/folders/s7/nhlmv2hx4vg32r27lhnh40t00000gn/T/ipykernel_70535/2952415658.py:3: UserWarning:
#
# `shade_lowest` has been replaced by `thresh`; setting `thresh=0.05.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data = flw[flw.species=='virginica'], x='sepal_length', y='sepal_width', shade=True, shade_lowest=False, cmap='Blues')
# /var/folders/s7/nhlmv2hx4vg32r27lhnh40t00000gn/T/ipykernel_70535/2952415658.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data = flw[flw.species=='virginica'], x='sepal_length', y='sepal_width', shade=True, shade_lowest=False, cmap='Blues')

# %%
plt.title('Daily bill')
sns.boxplot(data = tips, x='day', y='total_bill', hue='smoker')
plt.show()
