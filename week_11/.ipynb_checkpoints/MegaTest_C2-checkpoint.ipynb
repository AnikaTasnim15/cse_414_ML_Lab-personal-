# %% [markdown]
# # Part A — Digits Classification with DNN (MLP) (25 marks)
#
# Q1. Train an MLP on sklearn digits (25)
#
# Use sklearn.datasets.load_digits().
#
# 1. Load digits dataset (X, y). Normalize X to [0,1].
# 2. Split into train/test (80/20, stratify, fixed random_state).
# 3. Create TensorDataset + DataLoader for train and test.
# 4. Implement an MLP:
#
# * input 64 → 128 → 64 → 10 with ReLU
#
# 5. Train for 5 epochs using:
#
# * CrossEntropyLoss
# * Adam(lr=1e-3)
#
# 6. After each epoch print:
#
# * train loss, train accuracy
# * test accuracy

# %% [markdown]
# # Part B — DataLoader + Augmentation (Fashion-MNIST) (25 marks)
#
# Q2. Fashion-MNIST augmentation pipeline (25)
#
# Use torchvision.datasets.FashionMNIST.
#
# 1. Create train transforms that include:
#
# * Resize to 28x28 (still include it)
# * Random rotation (≤10 degrees)
# * ToTensor
#
# 2. Create test transforms that include:
#
# * ToTensor only
#
# 3. Load datasets and build DataLoaders:
#
# * train: batch_size=128, shuffle=True
# * test: batch_size=256, shuffle=False
#
# 4. Visualize 8 augmented train images in a grid with labels.

# %% [markdown]
# # Part D — TensorBoard Logging (15 marks)
#
# Q4. Log training metrics to TensorBoard (15)
#
# For Fashion-MNIST (you may use a simple CNN or MLP):
#
# 1. Train for 3 epochs.
# 2. Use SummaryWriter and log:
#
# * train loss (per epoch)
# * test accuracy (per epoch)
#
# 3. Write the TensorBoard command you would run to view logs.
#
# You must create logs under **./runs/**
