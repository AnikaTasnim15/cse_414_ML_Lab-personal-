# %%
import cv2, os

# %%
path = '../Data/BNG_9k/'
images = os.listdir(path+'images/')

# %%
path+images[0]
# Out:
# '../Data/BNG_9k/1.png'

# %%
cv2.imread(path+images[0])

# %%
for i in images:
    img = cv2.imread(path+images[0])
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, (224,224))
    print(i)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-6-e4ce66f5dd20> in <module>
#       1 for i in images:
#       2     img = cv2.imread(path+images[0])
# ----> 3     img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#       4     img = cv2.resize(img, (224,224))
#       5     print(i)
#
# error: OpenCV(4.5.1) C:\Users\appveyor\AppData\Local\Temp\1\pip-req-build-kh7iq4w7\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
im = cv2.imread(path+images[2])
print(im)
# Out:
# None

# %%
path+images[2]
# Out:
# '../Data/BNG_9k/100.png'
